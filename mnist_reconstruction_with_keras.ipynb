# %% [markdown]
# <a href="https://colab.research.google.com/github/Moostafaaa/images_reconstruction/blob/main/mnist_reconstruction_with_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
# from keras.datasets import boston_housing
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.optimizers import RMSprop

# %%
from keras.datasets import mnist
import numpy as np

# %%
from sklearn import preprocessing
from sklearn.preprocessing import scale

# %%
x_train_scaled = preprocessing.scale(x_train)
scaler = preprocessing.StandardScaler().fit(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
model = Sequential()
model.add(Dense(64, kernel_initializer='normal', activation='relu', input_shape=(13,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

# %%
model.compile(loss='mse',
 optimizer=RMSprop(),
 metrics=['mean_absolute_error'])

# %%
 import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
prediction = model.predict(x_test_scaled)
print(prediction.flatten())
print(y_test)
# Out:
# 4/4 [==============================] - 0s 6ms/step
# [ 8.821682  18.640387  20.808691  31.103859  24.125399  21.290453
#  28.05245   21.80281   18.708603  22.92261   20.564844  17.066938
#  16.257732  41.378574  19.988585  20.269175  24.450304  19.753727
#  19.690086  34.939987  12.125673  15.48981   21.676512  16.337069
#  20.407175  25.442253  28.308262  29.377022  11.455324  20.399927
#  19.339823  15.976223  31.012846  22.85217   19.073435   7.451915
#  15.462324  19.632822  19.205194  25.941616  29.516722  26.065477
#  14.058416  42.378475  27.41945   25.100176  25.835094  17.65414
#  23.622347  21.924196  35.313354  20.993263  11.233086  14.37438
#  34.28082   26.240767  12.771622  47.48209   31.253296  22.854177
#  21.925013  18.142757  15.047551  19.468134  22.806921  20.86304
#  13.005188  21.963266  13.985097   7.8359113 33.705196  30.958302
#  28.669916  13.778818  25.234194  18.925034  19.964613  23.045853
#  34.517437  10.13984   21.41839   37.246483  16.308804  13.9731045
#  17.263618  18.703173  24.725634  20.660833  21.543512  24.82609
#  20.159014  20.613361  24.66629   45.415066  34.597286  18.999239
#  34.448452  36.794464  25.040459  41.972458  29.889967  20.328072 ]
# [ 7.2 18.8 19.  27.  22.2 24.5 31.2 22.9 20.5 23.2 18.6 14.5 17.8 50.
#  20.8 24.3 24.2 19.8 19.1 22.7 12.  10.2 20.  18.5 20.9 23.  27.5 30.1
#   9.5 22.  21.2 14.1 33.1 23.4 20.1  7.4 15.4 23.8 20.1 24.5 33.  28.4
#  14.1 46.7 32.5 29.6 28.4 19.8 20.2 25.  35.4 20.3  9.7 14.5 34.9 26.6
#   7.2 50.  32.4 21.6 29.8 13.1 27.5 21.2 23.1 21.9 13.  23.2  8.1  5.6
#  21.7 29.6 19.6  7.  26.4 18.9 20.9 28.1 35.4 10.2 24.3 43.1 17.6 15.4
#  16.2 27.1 21.4 21.5 22.4 25.  16.6 18.6 22.  42.8 35.1 21.5 36.  21.9
#  24.1 50.  26.7 25. ]

# %%
from keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# x_train = x_train.reshape(60000, 784)
# x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# %%
from keras.layers import Conv2D, MaxPooling2D

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=(28,28,1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
 optimizer=keras.optimizers.Adadelta(),
 metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
 batch_size=128,
epochs=20,
verbose=1,
validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 469/469 [==============================] - 14s 10ms/step - loss: 2.2757 - accuracy: 0.1283 - val_loss: 2.2313 - val_accuracy: 0.2399
# Epoch 2/20
# 469/469 [==============================] - 4s 9ms/step - loss: 2.2056 - accuracy: 0.2374 - val_loss: 2.1421 - val_accuracy: 0.5882
# Epoch 3/20
# 469/469 [==============================] - 4s 9ms/step - loss: 2.1129 - accuracy: 0.3671 - val_loss: 2.0231 - val_accuracy: 0.7055
# Epoch 4/20
# 469/469 [==============================] - 4s 9ms/step - loss: 1.9919 - accuracy: 0.4638 - val_loss: 1.8673 - val_accuracy: 0.7299
# Epoch 5/20
# 469/469 [==============================] - 4s 9ms/step - loss: 1.8406 - accuracy: 0.5247 - val_loss: 1.6807 - val_accuracy: 0.7419
# Epoch 6/20
# 469/469 [==============================] - 4s 10ms/step - loss: 1.6728 - accuracy: 0.5725 - val_loss: 1.4783 - val_accuracy: 0.7629
# Epoch 7/20
# 469/469 [==============================] - 4s 9ms/step - loss: 1.5024 - accuracy: 0.6076 - val_loss: 1.2815 - val_accuracy: 0.7809
# Epoch 8/20
# 469/469 [==============================] - 4s 9ms/step - loss: 1.3453 - accuracy: 0.6399 - val_loss: 1.1094 - val_accuracy: 0.7950
# Epoch 9/20
# 469/469 [==============================] - 4s 9ms/step - loss: 1.2157 - accuracy: 0.6664 - val_loss: 0.9706 - val_accuracy: 0.8103
# Epoch 10/20
# 469/469 [==============================] - 4s 9ms/step - loss: 1.1120 - accuracy: 0.6815 - val_loss: 0.8620 - val_accuracy: 0.8232
# Epoch 11/20
# 469/469 [==============================] - 4s 9ms/step - loss: 1.0276 - accuracy: 0.7038 - val_loss: 0.7775 - val_accuracy: 0.8320
# Epoch 12/20
# 469/469 [==============================] - 4s 10ms/step - loss: 0.9589 - accuracy: 0.7172 - val_loss: 0.7110 - val_accuracy: 0.8391
# Epoch 13/20
# 469/469 [==============================] - 4s 9ms/step - loss: 0.9011 - accuracy: 0.7304 - val_loss: 0.6579 - val_accuracy: 0.8464
# Epoch 14/20
# 469/469 [==============================] - 4s 9ms/step - loss: 0.8573 - accuracy: 0.7428 - val_loss: 0.6156 - val_accuracy: 0.8517
# Epoch 15/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.8146 - accuracy: 0.7547 - val_loss: 0.5801 - val_accuracy: 0.8597
# Epoch 16/20
# 469/469 [==============================] - 5s 11ms/step - loss: 0.7815 - accuracy: 0.7638 - val_loss: 0.5502 - val_accuracy: 0.8652
# Epoch 17/20
# 469/469 [==============================] - 4s 10ms/step - loss: 0.7532 - accuracy: 0.7706 - val_loss: 0.5253 - val_accuracy: 0.8704
# Epoch 18/20
# 469/469 [==============================] - 4s 9ms/step - loss: 0.7273 - accuracy: 0.7803 - val_loss: 0.5037 - val_accuracy: 0.8744
# Epoch 19/20
# 469/469 [==============================] - 4s 9ms/step - loss: 0.7054 - accuracy: 0.7859 - val_loss: 0.4853 - val_accuracy: 0.8769
# Epoch 20/20
# 469/469 [==============================] - 5s 11ms/step - loss: 0.6844 - accuracy: 0.7929 - val_loss: 0.4689 - val_accuracy: 0.8798

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 64)       0
#  )
#
#  dropout (Dropout)           (None, 12, 12, 64)        0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 128)               1179776
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.imshow(x_test[1].reshape((28, 28)))
plt.show()

# %%
x_test[1].shape
# Out:
# (784,)

# %%
imgs = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
plt.imshow( imgs[1].reshape((28, 28)) )
plt.show()

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.15749606490135193
# Test accuracy: 0.9836999773979187

# %%
from keras.datasets import cifar10

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# %%
x_train[0].shape
# Out:
# (32, 32, 3)

# %%
model = Sequential()
model.add(Conv2D(16, kernel_size=(3, 3), activation='relu',input_shape=(32,32,3)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

# %%
opt = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)

# %%
model.compile(loss='categorical_crossentropy',
 optimizer=opt,
 metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
batch_size=128,
epochs=20,
verbose=1,
validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 391/391 [==============================] - 5s 11ms/step - loss: 1.5564 - accuracy: 0.4335 - val_loss: 1.2440 - val_accuracy: 0.5763
# Epoch 2/20
# 391/391 [==============================] - 3s 9ms/step - loss: 1.1493 - accuracy: 0.5946 - val_loss: 1.0520 - val_accuracy: 0.6402
# Epoch 3/20
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9937 - accuracy: 0.6476 - val_loss: 0.9633 - val_accuracy: 0.6704
# Epoch 4/20
# 391/391 [==============================] - 3s 8ms/step - loss: 0.8941 - accuracy: 0.6856 - val_loss: 0.9295 - val_accuracy: 0.6805
# Epoch 5/20
# 391/391 [==============================] - 4s 9ms/step - loss: 0.8184 - accuracy: 0.7127 - val_loss: 0.8646 - val_accuracy: 0.7063
# Epoch 6/20
# 391/391 [==============================] - 3s 8ms/step - loss: 0.7555 - accuracy: 0.7353 - val_loss: 0.8334 - val_accuracy: 0.7094
# Epoch 7/20
# 391/391 [==============================] - 3s 8ms/step - loss: 0.7021 - accuracy: 0.7539 - val_loss: 0.7921 - val_accuracy: 0.7234
# Epoch 8/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.6492 - accuracy: 0.7711 - val_loss: 0.7752 - val_accuracy: 0.7297
# Epoch 9/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.6003 - accuracy: 0.7878 - val_loss: 0.7837 - val_accuracy: 0.7287
# Epoch 10/20
# 391/391 [==============================] - 3s 8ms/step - loss: 0.5648 - accuracy: 0.7988 - val_loss: 0.7740 - val_accuracy: 0.7298
# Epoch 11/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.5232 - accuracy: 0.8135 - val_loss: 0.7915 - val_accuracy: 0.7237
# Epoch 12/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.4911 - accuracy: 0.8260 - val_loss: 0.7755 - val_accuracy: 0.7302
# Epoch 13/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.4597 - accuracy: 0.8336 - val_loss: 0.7813 - val_accuracy: 0.7351
# Epoch 14/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.4384 - accuracy: 0.8420 - val_loss: 0.8046 - val_accuracy: 0.7258
# Epoch 15/20
# 391/391 [==============================] - 4s 11ms/step - loss: 0.4028 - accuracy: 0.8560 - val_loss: 0.8276 - val_accuracy: 0.7293
# Epoch 16/20
# 391/391 [==============================] - 5s 13ms/step - loss: 0.3801 - accuracy: 0.8618 - val_loss: 0.8292 - val_accuracy: 0.7276
# Epoch 17/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.3626 - accuracy: 0.8683 - val_loss: 0.8716 - val_accuracy: 0.7254
# Epoch 18/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.3365 - accuracy: 0.8774 - val_loss: 0.8876 - val_accuracy: 0.7235
# Epoch 19/20
# 391/391 [==============================] - 4s 9ms/step - loss: 0.3164 - accuracy: 0.8864 - val_loss: 0.8975 - val_accuracy: 0.7311
# Epoch 20/20
# 391/391 [==============================] - 3s 8ms/step - loss: 0.3010 - accuracy: 0.8904 - val_loss: 0.9259 - val_accuracy: 0.7274

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 1.4354102611541748
# Test accuracy: 0.5199000239372253

# %%
# (x_train, _), (x_test, _) = mnist.load_data()

# x_train = x_train.astype('float32') / 255
# x_test = x_test.astype('float32') / 255
# x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
# x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
n = 20
plt.figure(figsize=(30, 3))
for i in range(10, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
history = model.fit(x_train_noisy, x_train,
 batch_size=128,
epochs=20,
verbose=1,
validation_data=(x_test_noisy, x_test))
# Out:
# Epoch 1/20
# 469/469 [==============================] - 3s 5ms/step - loss: 0.2275 - accuracy: 0.0103 - val_loss: 0.1743 - val_accuracy: 0.0102
# Epoch 2/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1612 - accuracy: 0.0126 - val_loss: 0.1499 - val_accuracy: 0.0104
# Epoch 3/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1458 - accuracy: 0.0113 - val_loss: 0.1412 - val_accuracy: 0.0118
# Epoch 4/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1383 - accuracy: 0.0103 - val_loss: 0.1354 - val_accuracy: 0.0118
# Epoch 5/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1334 - accuracy: 0.0106 - val_loss: 0.1332 - val_accuracy: 0.0141
# Epoch 6/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1300 - accuracy: 0.0118 - val_loss: 0.1303 - val_accuracy: 0.0126
# Epoch 7/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1275 - accuracy: 0.0110 - val_loss: 0.1285 - val_accuracy: 0.0106
# Epoch 8/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1253 - accuracy: 0.0118 - val_loss: 0.1274 - val_accuracy: 0.0140
# Epoch 9/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1233 - accuracy: 0.0119 - val_loss: 0.1256 - val_accuracy: 0.0142
# Epoch 10/20
# 469/469 [==============================] - 3s 5ms/step - loss: 0.1219 - accuracy: 0.0126 - val_loss: 0.1246 - val_accuracy: 0.0122
# Epoch 11/20
# 469/469 [==============================] - 3s 5ms/step - loss: 0.1205 - accuracy: 0.0129 - val_loss: 0.1236 - val_accuracy: 0.0132
# Epoch 12/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1194 - accuracy: 0.0136 - val_loss: 0.1233 - val_accuracy: 0.0144
# Epoch 13/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1184 - accuracy: 0.0137 - val_loss: 0.1230 - val_accuracy: 0.0148
# Epoch 14/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1175 - accuracy: 0.0141 - val_loss: 0.1224 - val_accuracy: 0.0153
# Epoch 15/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1167 - accuracy: 0.0137 - val_loss: 0.1223 - val_accuracy: 0.0131
# Epoch 16/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1160 - accuracy: 0.0144 - val_loss: 0.1217 - val_accuracy: 0.0151
# Epoch 17/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1153 - accuracy: 0.0143 - val_loss: 0.1214 - val_accuracy: 0.0133
# Epoch 18/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1148 - accuracy: 0.0150 - val_loss: 0.1211 - val_accuracy: 0.0155
# Epoch 19/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1143 - accuracy: 0.0141 - val_loss: 0.1208 - val_accuracy: 0.0152
# Epoch 20/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1138 - accuracy: 0.0146 - val_loss: 0.1215 - val_accuracy: 0.0141

# %%
newimgs = model.predict(x_test_noisy)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(newimgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
